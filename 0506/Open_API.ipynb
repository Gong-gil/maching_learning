# %% [markdown]
# ## API 크롤링

# %%
import json

data = '''
{
    "lastBuildDate": "Thu, 06 May 2021 14:39:52 +0900",
    "total": 542992,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "부산 지역 공공기관, 어버이날 앞두고 '효' 나눔",
            "originallink": "https://www.leaders.kr/news/articleView.html?idxno=242101",
            "link": "https://www.leaders.kr/news/articleView.html?idxno=242101",
            "description": "<b>어린이날</b>을 하루 앞둔 방문이었던만큼 '<b>어린이날</b> 맞이 치킨' 100마리도 함께 전달했다. 이 날 동원종합사회복지관 전달식에서는 정명희 부산 북구청장도 함께 참석해 BNK저축은행의 사회공헌활동에 대해 감사를 전하기도... ",
            "pubDate": "Thu, 06 May 2021 14:38:00 +0900"
        },
        {
            "title": "&quot;아동학대 아웃&quot; 김현철→루나, 앨범 '지켜줄게, 너를' 발매",
            "originallink": "http://www.sportsseoul.com/news/read/1039331?ref=naver",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=468&aid=0000766346",
            "description": "아동학대로 아파하는 아이들을 위해 김현철, 박기영, 홍경민, 루나, 츄더(문에스더) 등 선한 영양력을 나누려는 뮤지션들이 참여한 ‘지켜줄게, 너를’ 오프라인 앨범이 <b>어린이날</b> 다음날인 오늘(6일)에 출시된다.... ",
            "pubDate": "Thu, 06 May 2021 14:37:00 +0900"
        },
        {
            "title": "‘정대세♥’ 명서현, ‘골때녀’ 위해 한국 입국...2주 자가격리",
            "originallink": "http://star.mk.co.kr/new/view.php?mc=ST&year=2021&no=437216",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=009&aid=0004790059",
            "description": "<b>어린이날</b>도 반납하고 홀로 입국해 축구에 열중하는 그녀가 과연 새로운 시즌에서는 또 어떤 성장을 보여줄지 기대가 모아진다. 한편 ‘골(Goal) 때리는 그녀들’은 6월 중 첫 방송 예정이다. trdk0114@mk.co.kr '골때녀... ",
            "pubDate": "Thu, 06 May 2021 14:37:00 +0900"
        },
        {
            "title": "AI기술로 폭력현장 감지… 구리 CCTV관제센터 개관 후 검거율 10% 증가",
            "originallink": "https://www.donga.com/news/article/all/20210506/106792267/1",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=020&aid=0003355864",
            "description": "“어…저러다 큰일 <b>날</b> 것 같은데.” 지난달 1일 오후 10시 20분경. 경기 구리시 폐쇄회로(CC)TV... AI 지능형 CCTV는 주로 범죄 발생율이 높은 여성안심구역과 <b>어린이</b>보호구역 등에 집중 설치됐다. 홍영상 구리시... ",
            "pubDate": "Thu, 06 May 2021 14:37:00 +0900"
        },
        {
            "title": "'안정환♥' 이혜원, 샴페인 들고 가족 나들이 인증 &quot;감사한 나날&quot;",
            "originallink": "http://news.mt.co.kr/mtview.php?no=2021050614001090998",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=008&aid=0004583526",
            "description": "공개된 사진 속 이혜원은 남편 안정환과 함께 <b>어린이날</b>을 맞아 아이들과 외출한 모습이다. 야외 테이블에서 두 사람은 마주 보며 샴페인을 마시고 있다. 이혜원은 &quot;아들이 찍어줬다&quot;고 사진 설명을 덧붙이기도 했다. 특히... ",
            "pubDate": "Thu, 06 May 2021 14:36:00 +0900"
        },
        {
            "title": "순천시청소년수련관 어린이들, <b>어린이날</b> 맞아 맞춤형 선물받아",
            "originallink": "http://www.nspna.com/news/?mode=view&newsid=500308",
            "link": "http://www.nspna.com/news/?mode=view&newsid=500308",
            "description": "박종욱 기자, 순천시 청소년수련관 방과후아카데미 청소년(초등4~6학년)들은 5월 가정의 달을 맞아 훈훈한 <b>어린이날</b>을 보냈다. 승주청년회의소(회장 허동헌)에서는 <b>어린이날</b>을 맞이해 방과후아카데미 청소년(40명)들에게... ",
            "pubDate": "Thu, 06 May 2021 14:36:00 +0900"
        },
        {
            "title": "공주관광협회, <b>어린이날</b> 석장리박물관서 코로나19 예방 캠페인",
            "originallink": "http://www.ggilbo.com/news/articleView.html?idxno=845682",
            "link": "http://www.ggilbo.com/news/articleView.html?idxno=845682",
            "description": "안연옥 회장을 비롯한 공주시관광협의회 회원들이 <b>어린이날</b>인 지난 5일 석장리박물관을 찾아 사회적 거리두기 준수 등 코로나19 예방 캠페인을 펼치고 있다. 이건용 기자 공주시관광협의회는 <b>어린이날</b>인 지난 5일... ",
            "pubDate": "Thu, 06 May 2021 14:36:00 +0900"
        },
        {
            "title": "건강하게! 즐겁게! 하남시, 온택트로 열린 <b>어린이날</b> 행사 '큰 호응'",
            "originallink": "http://www.gukjenews.com/news/articleView.html?idxno=2217905",
            "link": "http://www.gukjenews.com/news/articleView.html?idxno=2217905",
            "description": "하남시, 온택트로 열린 <b>어린이날</b> 행사 '큰 호응' 하남시(시장 김상호)는 지난 5일 <b>어린이날</b> 행사 '온라인으로 놀아요'를 온택트 방식으로 진행해, 큰 호응 속 마무리됐다고 밝혔다. 하남시청 상황실에서 열린 이날 행사는... ",
            "pubDate": "Thu, 06 May 2021 14:36:00 +0900"
        },
        {
            "title": "고소영, 딸과 <b>어린이날</b> 데이트 인증샷",
            "originallink": "http://sports.khan.co.kr/news/sk_index.html?art_id=202105061435003&sec_id=540101&pt=nv",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=144&aid=0000734940",
            "description": "배우 고소영이 딸과 <b>어린이날</b> 산책한 일상을 공개했다. 고소영은 5일 자신의 SNS 인스타그램에 “<b>어린이날</b>. 아들은 친구랑 놀러 가고 우린 근처에서 어슬렁 어슬렁”이라는 글과 함께 딸과 함께 찍은 뒷모습 사진을... ",
            "pubDate": "Thu, 06 May 2021 14:36:00 +0900"
        },
        {
            "title": "소방청, <b>어린이날</b> 맞아 안전교육 콘텐츠 제작",
            "originallink": "http://fpn119.co.kr/156806",
            "link": "http://fpn119.co.kr/156806",
            "description": "© 소방청 제공 = 소방청(청장 신열우)은 <b>어린이날</b>을 맞아 유익하고 흥미로운 안전교육 콘텐츠를 제작해... 어린이 사이에서 인기가 높은 로보카 폴리의 캐릭터를 활용해 제작했다. 안전교육은 소방관은 무엇을 하는... ",
            "pubDate": "Thu, 06 May 2021 14:36:00 +0900"
        }
    ]
}
'''

json_data = json.loads(data)

print(json_data['items'][0]['title'])
print(json_data['items'][0]['link'])
print(json_data['items'][0]['description'])
# Out:
# 부산 지역 공공기관, 어버이날 앞두고 '효' 나눔
# https://www.leaders.kr/news/articleView.html?idxno=242101
# <b>어린이날</b>을 하루 앞둔 방문이었던만큼 '<b>어린이날</b> 맞이 치킨' 100마리도 함께 전달했다. 이 날 동원종합사회복지관 전달식에서는 정명희 부산 북구청장도 함께 참석해 BNK저축은행의 사회공헌활동에 대해 감사를 전하기도...

# %% [markdown]
# ## 네이버_OPEN_API로 크롤링하기

# %%
import requests
import pprint

client_id = 'ts8oLdNREuCnhjrd_e68'
client_secret = '1dL51JhCpE'

naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query=아이폰12'
header_params = {'X-Naver-Client-Id':client_id,'X-Naver-Client-Secret':client_secret}
res = requests.get(naver_open_api, headers = header_params)

if res.status_code == 200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print(index + 1, item['title'], item['link'])
else:
    print('ERROR CODE: ', res.status_code)
# Out:
# 1 “<b>아이폰</b> 새로운 색깔 나오자 좌절한 태연… 결국 뜻밖의 사진 올렸다” https://www.wikitree.co.kr/articles/646021
# 2 &quot;13 퍼플, 프로 아니었으면&quot;…태연, <b>아이폰12</b> 퍼플 결국 구매 http://www.topstarnews.net/news/articleView.html?idxno=2800100
# 3 폰지점프, <b>아이폰12</b> 퍼플 출시…핸드폰 싸게 사는 법 공유 http://www.it-b.co.kr/news/articleView.html?idxno=49242
# 4 SK텔레콤, LG 폰 '클럽 기변' 갤럭시·<b>아이폰</b> 교체 지원 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=030&aid=0002943149
# 5 '한강 사망 의대생의 아버지가 이상하다면서 제기한 의문점이 13개나 됩니다' https://www.wikitree.co.kr/articles/645883
# 6 &quot;<b>아이폰</b>13 프로맥스, 노치 작아지고 카메라 모듈은 커졌다&quot; https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=092&aid=0002221276
# 7 SKT, LG폰 중고보상 프로그램으로 갤폴드·<b>아이폰</b> 교체해준다 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0012376170
# 8 [영상] '<b>아이폰</b>13 프로' 목업 핸즈온…노치 작아지고 카메라 커졌다 http://kbench.com/?q=node/220991
# 9 [팀장시각] 국민의 경찰 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=016&aid=0001831648
# ...

# %% [markdown]
# * 옵션을 추가로 넣었다

# %%
import requests
import pprint

client_id = 'ts8oLdNREuCnhjrd_e68'
client_secret = '1dL51JhCpE'

naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query=아이폰12&display=100&start=1'
header_params = {'X-Naver-Client-Id':client_id,'X-Naver-Client-Secret':client_secret}
res = requests.get(naver_open_api, headers = header_params)

if res.status_code == 200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print(index + 1, item['title'], item['link'])
else:
    print('ERROR CODE: ', res.status_code)
# Out:
# 1 “<b>아이폰</b> 새로운 색깔 나오자 좌절한 태연… 결국 뜻밖의 사진 올렸다” https://www.wikitree.co.kr/articles/646021
# 2 &quot;13 퍼플, 프로 아니었으면&quot;…태연, <b>아이폰12</b> 퍼플 결국 구매 http://www.topstarnews.net/news/articleView.html?idxno=2800100
# 3 폰지점프, <b>아이폰12</b> 퍼플 출시…핸드폰 싸게 사는 법 공유 http://www.it-b.co.kr/news/articleView.html?idxno=49242
# 4 SK텔레콤, LG 폰 '클럽 기변' 갤럭시·<b>아이폰</b> 교체 지원 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=030&aid=0002943149
# 5 '한강 사망 의대생의 아버지가 이상하다면서 제기한 의문점이 13개나 됩니다' https://www.wikitree.co.kr/articles/645883
# 6 &quot;<b>아이폰</b>13 프로맥스, 노치 작아지고 카메라 모듈은 커졌다&quot; https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=092&aid=0002221276
# 7 SKT, LG폰 중고보상 프로그램으로 갤폴드·<b>아이폰</b> 교체해준다 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0012376170
# 8 [영상] '<b>아이폰</b>13 프로' 목업 핸즈온…노치 작아지고 카메라 커졌다 http://kbench.com/?q=node/220991
# 9 [팀장시각] 국민의 경찰 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=016&aid=0001831648
# ...

# %% [markdown]
# ---
# * 엑셀 저장해보자
# ---

# %%
import openpyxl
import requests

client_id = 'ts8oLdNREuCnhjrd_e68'
client_secret = '1dL51JhCpE'
start, num = 1, 0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions['B'].width = 100
excel_sheet.column_dimensions['C'].width = 100
excel_sheet.append(['랭팅','제목','링크'])   

for index in range(10):
    start_number = start + (index * 100)
    naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query=아이폰12&display=100&start=1'
    header_params = {'X-Naver-Client-Id':client_id,'X-Naver-Client-Secret':client_secret}
    res = requests.get(naver_open_api, headers = header_params)
    if res.status_code == 200:
        data = res.json()
        for index, item in enumerate(data['items']):
            num += 1
            print(index + 1, item['title'], item['link'])
    else:
        print('ERROR CODE', res.status_code)
    
excel_file.save('iphone.xlsx')
excel_file.close()
# Out:
# 1 “<b>아이폰</b> 새로운 색깔 나오자 좌절한 태연… 결국 뜻밖의 사진 올렸다” https://www.wikitree.co.kr/articles/646021
# 2 &quot;13 퍼플, 프로 아니었으면&quot;…태연, <b>아이폰12</b> 퍼플 결국 구매 http://www.topstarnews.net/news/articleView.html?idxno=2800100
# 3 폰지점프, <b>아이폰12</b> 퍼플 출시…핸드폰 싸게 사는 법 공유 http://www.it-b.co.kr/news/articleView.html?idxno=49242
# 4 SK텔레콤, LG 폰 '클럽 기변' 갤럭시·<b>아이폰</b> 교체 지원 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=030&aid=0002943149
# 5 '한강 사망 의대생의 아버지가 이상하다면서 제기한 의문점이 13개나 됩니다' https://www.wikitree.co.kr/articles/645883
# 6 &quot;<b>아이폰</b>13 프로맥스, 노치 작아지고 카메라 모듈은 커졌다&quot; https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=092&aid=0002221276
# 7 SKT, LG폰 중고보상 프로그램으로 갤폴드·<b>아이폰</b> 교체해준다 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0012376170
# 8 [영상] '<b>아이폰</b>13 프로' 목업 핸즈온…노치 작아지고 카메라 커졌다 http://kbench.com/?q=node/220991
# 9 [팀장시각] 국민의 경찰 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=016&aid=0001831648
# ...
